# %%
from transformers import pipeline
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
summary = summarizer(transcript, max_length=50, min_length=25, do_sample=False)[0]['summary_text']

# %%
# !pip install yt-dlp
# !pip install git+https://github.com/openai/whisper.git
# !pip install opencv-python
# !pip install transformers==4.38.2 accelerate==0.27.2 timm==0.9.12
# !pip install sentence-transformers==2.5.0
# !pip install git+https://github.com/openai/CLIP.git
# !pip install torch torchvision Pillow
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-q64lyyrx
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-q64lyyrx
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-22i6vvnl
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-22i6vvnl
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...

# %%
import yt_dlp
import whisper
import cv2
from sentence_transformers import SentenceTransformer
import clip
import torch
from PIL import Image
from sklearn.metrics.pairwise import cosine_similarity

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
# Download audio
def download_audio(url):
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': 'audio.%(ext)s',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])
    return "audio.mp3"

# Summarize text
def summarize_text(text, num_sentences=3):
    sentences = text.split(". ")
    embeddings = text_model.encode(sentences)
    sentence_scores = cosine_similarity(embeddings).sum(axis=0)
    top_indices = sentence_scores.argsort()[-num_sentences:]
    summary = ". ".join([sentences[i] for i in sorted(top_indices)]) + "."
    return summary

# Main execution
youtube_url = "https://youtu.be/1F3hm6MfR1k?si=BHNp1-MvWSn847TR"
audio_file = download_audio(youtube_url)

# Transcribe
model = whisper.load_model("base")
result = model.transcribe(audio_file)
transcript = result["text"]
print("Transcript:", transcript)

# Embed and summarize
text_model = SentenceTransformer('all-MiniLM-L6-v2')
summary = summarize_text(transcript)
print("Summary:", summary)
# Out:
# [youtube] Extracting URL: https://youtu.be/1F3hm6MfR1k?si=BHNp1-MvWSn847TR
# [youtube] 1F3hm6MfR1k: Downloading webpage
# [youtube] 1F3hm6MfR1k: Downloading tv client config
# [youtube] 1F3hm6MfR1k: Downloading player 73381ccc-main
# [youtube] 1F3hm6MfR1k: Downloading tv player API JSON
# [youtube] 1F3hm6MfR1k: Downloading ios player API JSON
# [youtube] 1F3hm6MfR1k: Downloading m3u8 information
# [info] 1F3hm6MfR1k: Downloading 1 format(s): 251
# [download] Destination: audio.webm
# [download] 100% of    3.08MiB in 00:00:00 at 7.76MiB/s
# [ExtractAudio] Destination: audio.mp3
# Deleting original file audio.webm (pass -k to keep)
# ...
